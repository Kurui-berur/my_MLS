# %% [markdown]
# <a href="https://colab.research.google.com/github/Kurui-berur/my_MLS/blob/main/oedema.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INTRODUCTION

# %% [markdown]
# This project aims to simply buld a computational/probabilistic framework for oedema in SCI patients. motivated by the question can we Developed a probabilistic computational model of oedema in paralyzed patients, treating interstitial fluid accumulation as a stochastic dynamical process influenced by lymphatic drainage, capillary permeability, and environmental factors. Implemented Monte Carlo simulations to estimate oedema risk over time and explored predictive interventions that shift probability distributions toward physiological balance.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
/path

# %% [markdown]
# # New Section
